# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.6 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 78.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 102.4 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split
import gensim.downloader as api

# ===== 1. Load dataset =====
data = pd.read_csv("balanced_dataset.csv")
texts = data['title'].astype(str).tolist()
labels = data['isBiased'].values

# ===== 2. Tokenization =====
max_words = 8000
max_len = 120

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

# ===== 3. Train/Validation Split =====
X_train, X_val, y_train, y_val = train_test_split(
    padded, labels, test_size=0.2, random_state=42, stratify=labels
)

# ===== 4. Load Pretrained Word2Vec =====
print("Loading Google News Word2Vec model... (~1.5GB)")
w2v_model = api.load("word2vec-google-news-300")
embedding_dim = 300

# ===== 5. Build Embedding Matrix =====
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < max_words and word in w2v_model.key_to_index:
        embedding_matrix[i] = w2v_model[word]

# ===== 6. Define LSTM → GRU model =====
model = Sequential([
    Embedding(input_dim=max_words,
              output_dim=embedding_dim,
              weights=[embedding_matrix],
              input_length=max_len,
              trainable=False),

    # Forward LSTM
    LSTM(128, return_sequences=True,
         dropout=0.1, recurrent_dropout=0.1,
         kernel_regularizer=regularizers.l2(0.01)),

    Dropout(0.2),

    # GRU layer
    GRU(64, return_sequences=False,
        dropout=0.1, recurrent_dropout=0.1),

    # Dense layers
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# ===== 7. Callbacks =====
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)

# ===== 8. Train =====
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ===== 9. Plot Training vs Validation Loss/Accuracy =====
plt.figure(figsize=(12,5))

# Loss curve
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# Accuracy curve
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curve")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# ===== 10. Evaluation =====
y_pred_probs = model.predict(X_val)
y_pred = (y_pred_probs > 0.5).astype(int)

print("\nClassification Report:\n")
print(classification_report(y_val, y_pred, digits=4))

cm = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Biased (0)', 'Biased (1)'],
            yticklabels=['Not Biased (0)', 'Biased (1)'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Loading Google News Word2Vec model... (~1.5GB)
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │     2,400,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,400,000 (9.16 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,400,000 (9.16 MB)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 892ms/step - accuracy: 0.4662 - loss: 3.7770 - val_accuracy: 0.5000 - val_loss: 2.1155 - learning_rate: 0.0010
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 687ms/step - accuracy: 0.4954 - loss: 1.8033 - val_accuracy: 0.5000 - val_loss: 1.1331 - learning_rate: 0.0010
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 448ms/step - accuracy: 0.5035 - loss: 1.0250 - val_accuracy: 0.5000 - val_loss: 0.8068 - learning_rate: 0.0010
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 449ms/step - accuracy: 0.4676 - loss: 0.7761 - val_accuracy: 0.5000 - val_loss: 0.7172 - learning_rate: 0.0010
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 428ms/step - accuracy: 0.4740 - loss: 0.7105 - val_accuracy: 0.5000 - val_loss: 0.6972 - learning_rate: 0.0010
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 436ms/step - accuracy: 0.4951 - loss: 0.6963 - val_accuracy: 0.5000 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 429ms/step - accuracy: 0.4857 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 414ms/step - accuracy: 0.5118 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.4889 - loss: 0.6933
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - accuracy: 0.4885 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 426ms/step - accuracy: 0.4960 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 5.0000e-04
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.4455 - loss: 0.6937
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - accuracy: 0.4465 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 5.0000e-04
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 430ms/step - accuracy: 0.5083 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.5000e-04
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.4727 - loss: 0.6932
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 412ms/step - accuracy: 0.4730 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 2.5000e-04
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - accuracy: 0.5023 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 1.2500e-04
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.4925 - loss: 0.6931
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 425ms/step - accuracy: 0.4924 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 1.2500e-04
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - accuracy: 0.4722 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 6.2500e-05
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.4863 - loss: 0.6932
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 428ms/step - accuracy: 0.4865 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 6.2500e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.5000    1.0000    0.6667       100
#            1     0.0000    0.0000    0.0000       100
#
#     accuracy                         0.5000       200
#    macro avg     0.2500    0.5000    0.3333       200
# weighted avg     0.2500    0.5000    0.3333       200
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # BILSTM with Attention - 00

# %%
# ===== 0. Imports =====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import os, requests, zipfile

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, Input, Layer
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

# ===== 1. Download GloVe (100d) =====
glove_path = "glove.6B.100d.txt"
if not os.path.exists(glove_path):
    print("Downloading GloVe embeddings (~822MB zip)...")
    url = "http://nlp.stanford.edu/data/glove.6B.zip"
    r = requests.get(url, stream=True)
    with open("glove.6B.zip", "wb") as f:
        for chunk in r.iter_content(chunk_size=1024):
            if chunk:
                f.write(chunk)
    print("Extracting GloVe...")
    with zipfile.ZipFile("glove.6B.zip", "r") as zip_ref:
        zip_ref.extractall(".")
    print("GloVe ready!")

# ===== 2. Load Dataset =====
data = pd.read_csv("balanced_dataset.csv")  # must exist in Colab
labels = data['isBiased'].values.astype(int).reshape(-1,1)

# ===== 3. Preprocessing =====
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text

texts = [clean_text(t) for t in data['title'].astype(str)]

# ===== 4. Tokenization =====
max_words = 2000
max_len = 30
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

# ===== 5. Train/Validation Split =====
X_train, X_val, y_train, y_val = train_test_split(
    padded, labels, test_size=0.2, random_state=42, stratify=labels
)

# ===== 6. Load GloVe Embeddings =====
embedding_index = {}
with open(glove_path, encoding="utf8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = vector

embedding_dim = 100
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < max_words:
        vec = embedding_index.get(word)
        if vec is not None:
            embedding_matrix[i] = vec

# ===== 7. F1 Callback =====
class F1Metrics(Callback):
    def on_train_begin(self, logs=None):
        self.train_f1s = []
        self.val_f1s = []

    def on_epoch_end(self, epoch, logs=None):
        y_train_pred = (self.model.predict(X_train, verbose=0) > 0.5).astype(int)
        y_val_pred = (self.model.predict(X_val, verbose=0) > 0.5).astype(int)
        self.train_f1s.append(f1_score(y_train, y_train_pred))
        self.val_f1s.append(f1_score(y_val, y_val_pred))
        print(f" — train_f1: {self.train_f1s[-1]:.4f} — val_f1: {self.val_f1s[-1]:.4f}")

f1_callback = F1Metrics()

# ===== 8. Custom Attention Layer =====
class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(
            name="att_weight", shape=(input_shape[-1], 1),
            initializer="glorot_uniform", trainable=True
        )
        self.b = self.add_weight(
            name="att_bias", shape=(input_shape[1], 1),
            initializer="zeros", trainable=True
        )
        super(Attention, self).build(input_shape)

    def call(self, x):
        e = K.tanh(K.dot(x, self.W) + self.b)
        alpha = K.softmax(e, axis=1)
        context = x * alpha
        return K.sum(context, axis=1)

# ===== 9. Build BiLSTM + Attention Model =====
def build_bilstm_attention(max_words, embedding_dim, max_len, embedding_matrix):
    inputs = Input(shape=(max_len,))

    x = Embedding(input_dim=max_words,
                  output_dim=embedding_dim,
                  weights=[embedding_matrix],
                  input_length=max_len,
                  trainable=True)(inputs)

    x = Bidirectional(LSTM(32, return_sequences=True, dropout=0.4, recurrent_dropout=0.3))(x)

    x = Attention()(x)

    x = Dense(32, activation='relu', kernel_regularizer='l2')(x)
    x = Dropout(0.5)(x)

    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    optimizer = Adam(learning_rate=1e-4, clipnorm=1.0)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

model = build_bilstm_attention(max_words, embedding_dim, max_len, embedding_matrix)
model.summary()

# ===== 10. Callbacks =====
early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)

# ===== 11. Training =====
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr, f1_callback],
    verbose=1
)

# ===== 12. Plot Loss & F1 =====
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1,2,2)
plt.plot(f1_callback.train_f1s, label='train_f1')
plt.plot(f1_callback.val_f1s, label='val_f1')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Score Curve')
plt.legend()
plt.show()

# ===== 13. Evaluation =====
y_pred = (model.predict(X_val) > 0.5).astype(int)
print(classification_report(y_val, y_pred, digits=4))

cm = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Biased','Biased'],
            yticklabels=['Not Biased','Biased'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Downloading GloVe embeddings (~822MB zip)...
# Extracting GloVe...
# GloVe ready!
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, 30, 100)        │       200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 30, 64)         │        34,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention (Attention)           │ (None, 64)             │            94 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 236,255 (922.87 KB)
#  Trainable params: 236,255 (922.87 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4997 - loss: 1.1172 — train_f1: 0.6695 — val_f1: 0.6667
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 261ms/step - accuracy: 0.5000 - loss: 1.1170 - val_accuracy: 0.5150 - val_loss: 1.1050 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5327 - loss: 1.1013 — train_f1: 0.6757 — val_f1: 0.6618
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - accuracy: 0.5318 - loss: 1.1013 - val_accuracy: 0.5350 - val_loss: 1.0921 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5027 - loss: 1.0931 — train_f1: 0.6826 — val_f1: 0.6587
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.5026 - loss: 1.0930 - val_accuracy: 0.5700 - val_loss: 1.0797 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5095 - loss: 1.0803 — train_f1: 0.6962 — val_f1: 0.6610
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 197ms/step - accuracy: 0.5102 - loss: 1.0802 - val_accuracy: 0.6000 - val_loss: 1.0677 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5937 - loss: 1.0642 — train_f1: 0.6831 — val_f1: 0.6726
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.5934 - loss: 1.0641 - val_accuracy: 0.6350 - val_loss: 1.0558 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5611 - loss: 1.0555 — train_f1: 0.6382 — val_f1: 0.6333
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.5612 - loss: 1.0554 - val_accuracy: 0.6700 - val_loss: 1.0444 - learning_rate: 1.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5632 - loss: 1.0449 — train_f1: 0.6401 — val_f1: 0.6437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.5617 - loss: 1.0449 - val_accuracy: 0.6900 - val_loss: 1.0330 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5540 - loss: 1.0337 — train_f1: 0.7079 — val_f1: 0.6842
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.5542 - loss: 1.0336 - val_accuracy: 0.7000 - val_loss: 1.0217 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5628 - loss: 1.0238 — train_f1: 0.7332 — val_f1: 0.7411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 213ms/step - accuracy: 0.5630 - loss: 1.0237 - val_accuracy: 0.7450 - val_loss: 1.0106 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6010 - loss: 1.0147 — train_f1: 0.7173 — val_f1: 0.7273
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 269ms/step - accuracy: 0.6000 - loss: 1.0146 - val_accuracy: 0.7450 - val_loss: 0.9996 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6286 - loss: 0.9999 — train_f1: 0.7632 — val_f1: 0.7800
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.6281 - loss: 0.9998 - val_accuracy: 0.7800 - val_loss: 0.9881 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6600 - loss: 0.9890 — train_f1: 0.7316 — val_f1: 0.7568
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - accuracy: 0.6602 - loss: 0.9889 - val_accuracy: 0.7750 - val_loss: 0.9761 - learning_rate: 1.0000e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6361 - loss: 0.9786 — train_f1: 0.7164 — val_f1: 0.7514
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.6358 - loss: 0.9786 - val_accuracy: 0.7850 - val_loss: 0.9641 - learning_rate: 1.0000e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6132 - loss: 0.9698 — train_f1: 0.7887 — val_f1: 0.8182
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.6140 - loss: 0.9696 - val_accuracy: 0.8200 - val_loss: 0.9508 - learning_rate: 1.0000e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6374 - loss: 0.9594 — train_f1: 0.7800 — val_f1: 0.8063
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.6390 - loss: 0.9591 - val_accuracy: 0.8150 - val_loss: 0.9369 - learning_rate: 1.0000e-04
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6364 - loss: 0.9452 — train_f1: 0.8307 — val_f1: 0.8263
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 264ms/step - accuracy: 0.6370 - loss: 0.9451 - val_accuracy: 0.8150 - val_loss: 0.9218 - learning_rate: 1.0000e-04
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7070 - loss: 0.9283 — train_f1: 0.8340 — val_f1: 0.8235
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.7070 - loss: 0.9281 - val_accuracy: 0.8200 - val_loss: 0.9046 - learning_rate: 1.0000e-04
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7232 - loss: 0.9119 — train_f1: 0.8401 — val_f1: 0.8350
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.7226 - loss: 0.9119 - val_accuracy: 0.8300 - val_loss: 0.8846 - learning_rate: 1.0000e-04
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7269 - loss: 0.8916 — train_f1: 0.8475 — val_f1: 0.8473
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.7265 - loss: 0.8916 - val_accuracy: 0.8450 - val_loss: 0.8606 - learning_rate: 1.0000e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7602 - loss: 0.8705 — train_f1: 0.8554 — val_f1: 0.8416
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.7596 - loss: 0.8704 - val_accuracy: 0.8400 - val_loss: 0.8322 - learning_rate: 1.0000e-04
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7429 - loss: 0.8605 — train_f1: 0.8582 — val_f1: 0.8500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 272ms/step - accuracy: 0.7437 - loss: 0.8600 - val_accuracy: 0.8500 - val_loss: 0.7991 - learning_rate: 1.0000e-04
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7773 - loss: 0.8284 — train_f1: 0.8706 — val_f1: 0.8543
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 182ms/step - accuracy: 0.7775 - loss: 0.8279 - val_accuracy: 0.8550 - val_loss: 0.7596 - learning_rate: 1.0000e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7941 - loss: 0.7919 — train_f1: 0.8752 — val_f1: 0.8586
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.7940 - loss: 0.7916 - val_accuracy: 0.8600 - val_loss: 0.7151 - learning_rate: 1.0000e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7677 - loss: 0.7803 — train_f1: 0.8827 — val_f1: 0.8586
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 188ms/step - accuracy: 0.7689 - loss: 0.7792 - val_accuracy: 0.8600 - val_loss: 0.6733 - learning_rate: 1.0000e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7851 - loss: 0.7270 — train_f1: 0.8875 — val_f1: 0.8673
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.7858 - loss: 0.7267 - val_accuracy: 0.8700 - val_loss: 0.6289 - learning_rate: 1.0000e-04
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8147 - loss: 0.7009 — train_f1: 0.8966 — val_f1: 0.8691
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8149 - loss: 0.7006 - val_accuracy: 0.8750 - val_loss: 0.5933 - learning_rate: 1.0000e-04
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8197 - loss: 0.6785 — train_f1: 0.9009 — val_f1: 0.8691
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 260ms/step - accuracy: 0.8203 - loss: 0.6778 - val_accuracy: 0.8750 - val_loss: 0.5631 - learning_rate: 1.0000e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8110 - loss: 0.6501 — train_f1: 0.9009 — val_f1: 0.8691
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 185ms/step - accuracy: 0.8118 - loss: 0.6495 - val_accuracy: 0.8750 - val_loss: 0.5404 - learning_rate: 1.0000e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8410 - loss: 0.6036 — train_f1: 0.9026 — val_f1: 0.8750
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.8416 - loss: 0.6033 - val_accuracy: 0.8800 - val_loss: 0.5226 - learning_rate: 1.0000e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8528 - loss: 0.5866 — train_f1: 0.8993 — val_f1: 0.8737
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.8524 - loss: 0.5872 - val_accuracy: 0.8800 - val_loss: 0.5075 - learning_rate: 1.0000e-04
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8760 - loss: 0.5648 — train_f1: 0.9026 — val_f1: 0.8737
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8750 - loss: 0.5657 - val_accuracy: 0.8800 - val_loss: 0.4967 - learning_rate: 1.0000e-04
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8509 - loss: 0.5865 — train_f1: 0.9054 — val_f1: 0.8750
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.8513 - loss: 0.5860 - val_accuracy: 0.8800 - val_loss: 0.4888 - learning_rate: 1.0000e-04
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8881 - loss: 0.5283 — train_f1: 0.9100 — val_f1: 0.8737
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8875 - loss: 0.5289 - val_accuracy: 0.8800 - val_loss: 0.4772 - learning_rate: 1.0000e-04
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8510 - loss: 0.5639 — train_f1: 0.9119 — val_f1: 0.8737
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.8518 - loss: 0.5629 - val_accuracy: 0.8800 - val_loss: 0.4699 - learning_rate: 1.0000e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8440 - loss: 0.5592 — train_f1: 0.9131 — val_f1: 0.8737
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.8444 - loss: 0.5590 - val_accuracy: 0.8800 - val_loss: 0.4622 - learning_rate: 1.0000e-04
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8785 - loss: 0.5118 — train_f1: 0.9179 — val_f1: 0.8912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.8783 - loss: 0.5118 - val_accuracy: 0.8950 - val_loss: 0.4558 - learning_rate: 1.0000e-04
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8775 - loss: 0.5247 — train_f1: 0.9193 — val_f1: 0.8912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 197ms/step - accuracy: 0.8774 - loss: 0.5244 - val_accuracy: 0.8950 - val_loss: 0.4487 - learning_rate: 1.0000e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8752 - loss: 0.4857 — train_f1: 0.9254 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.8753 - loss: 0.4860 - val_accuracy: 0.8900 - val_loss: 0.4449 - learning_rate: 1.0000e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9046 - loss: 0.4693 — train_f1: 0.9276 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9041 - loss: 0.4702 - val_accuracy: 0.8900 - val_loss: 0.4372 - learning_rate: 1.0000e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8711 - loss: 0.4834 — train_f1: 0.9207 — val_f1: 0.8830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.8712 - loss: 0.4832 - val_accuracy: 0.8900 - val_loss: 0.4291 - learning_rate: 1.0000e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8599 - loss: 0.4920 — train_f1: 0.9315 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.8610 - loss: 0.4911 - val_accuracy: 0.8900 - val_loss: 0.4248 - learning_rate: 1.0000e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9008 - loss: 0.4561 — train_f1: 0.9338 — val_f1: 0.8912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9009 - loss: 0.4557 - val_accuracy: 0.8950 - val_loss: 0.4193 - learning_rate: 1.0000e-04
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9131 - loss: 0.4402 — train_f1: 0.9354 — val_f1: 0.8912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 188ms/step - accuracy: 0.9125 - loss: 0.4408 - val_accuracy: 0.8950 - val_loss: 0.4151 - learning_rate: 1.0000e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8922 - loss: 0.4399 — train_f1: 0.9361 — val_f1: 0.8889
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8920 - loss: 0.4398 - val_accuracy: 0.8950 - val_loss: 0.4087 - learning_rate: 1.0000e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8894 - loss: 0.4461 — train_f1: 0.9374 — val_f1: 0.8842
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 219ms/step - accuracy: 0.8889 - loss: 0.4467 - val_accuracy: 0.8900 - val_loss: 0.4045 - learning_rate: 1.0000e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8836 - loss: 0.4580 — train_f1: 0.9376 — val_f1: 0.8842
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.8834 - loss: 0.4578 - val_accuracy: 0.8900 - val_loss: 0.3990 - learning_rate: 1.0000e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8834 - loss: 0.4426 — train_f1: 0.9433 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.8839 - loss: 0.4421 - val_accuracy: 0.8900 - val_loss: 0.3987 - learning_rate: 1.0000e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8998 - loss: 0.4327  — train_f1: 0.9422 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.8998 - loss: 0.4320 - val_accuracy: 0.8900 - val_loss: 0.3973 - learning_rate: 1.0000e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9001 - loss: 0.4039 — train_f1: 0.9440 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.9001 - loss: 0.4045 - val_accuracy: 0.8850 - val_loss: 0.3907 - learning_rate: 1.0000e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9015 - loss: 0.4048 — train_f1: 0.9440 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.9018 - loss: 0.4043 - val_accuracy: 0.8850 - val_loss: 0.3871 - learning_rate: 1.0000e-04
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9169 - loss: 0.4064 — train_f1: 0.9454 — val_f1: 0.8796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9165 - loss: 0.4066 - val_accuracy: 0.8850 - val_loss: 0.3832 - learning_rate: 1.0000e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9090 - loss: 0.3755 — train_f1: 0.9451 — val_f1: 0.8796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9089 - loss: 0.3757 - val_accuracy: 0.8850 - val_loss: 0.3793 - learning_rate: 1.0000e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9216 - loss: 0.3655 — train_f1: 0.9494 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.9214 - loss: 0.3661 - val_accuracy: 0.8850 - val_loss: 0.3794 - learning_rate: 1.0000e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9097 - loss: 0.3660 — train_f1: 0.9494 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9096 - loss: 0.3663 - val_accuracy: 0.8850 - val_loss: 0.3756 - learning_rate: 1.0000e-04
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9096 - loss: 0.3768 — train_f1: 0.9515 — val_f1: 0.8796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 214ms/step - accuracy: 0.9094 - loss: 0.3772 - val_accuracy: 0.8850 - val_loss: 0.3712 - learning_rate: 1.0000e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9119 - loss: 0.3747 — train_f1: 0.9541 — val_f1: 0.8796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 179ms/step - accuracy: 0.9121 - loss: 0.3743 - val_accuracy: 0.8850 - val_loss: 0.3693 - learning_rate: 1.0000e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9246 - loss: 0.3542 — train_f1: 0.9554 — val_f1: 0.8750
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9243 - loss: 0.3544 - val_accuracy: 0.8800 - val_loss: 0.3675 - learning_rate: 1.0000e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9212 - loss: 0.3576 — train_f1: 0.9567 — val_f1: 0.8750
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.9212 - loss: 0.3576 - val_accuracy: 0.8800 - val_loss: 0.3634 - learning_rate: 1.0000e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9390 - loss: 0.3117 — train_f1: 0.9545 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.9386 - loss: 0.3128 - val_accuracy: 0.8850 - val_loss: 0.3614 - learning_rate: 1.0000e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9310 - loss: 0.3338 — train_f1: 0.9581 — val_f1: 0.8750
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.9308 - loss: 0.3345 - val_accuracy: 0.8800 - val_loss: 0.3580 - learning_rate: 1.0000e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9083 - loss: 0.3492 — train_f1: 0.9558 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9086 - loss: 0.3489 - val_accuracy: 0.8850 - val_loss: 0.3568 - learning_rate: 1.0000e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9264 - loss: 0.3251 — train_f1: 0.9582 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.9266 - loss: 0.3251 - val_accuracy: 0.8850 - val_loss: 0.3557 - learning_rate: 1.0000e-04
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9210 - loss: 0.3246 — train_f1: 0.9594 — val_f1: 0.8750
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - accuracy: 0.9210 - loss: 0.3250 - val_accuracy: 0.8800 - val_loss: 0.3514 - learning_rate: 1.0000e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9227 - loss: 0.3396 — train_f1: 0.9612 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.9230 - loss: 0.3389 - val_accuracy: 0.8850 - val_loss: 0.3534 - learning_rate: 1.0000e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9400 - loss: 0.3173 — train_f1: 0.9619 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9395 - loss: 0.3176 - val_accuracy: 0.8850 - val_loss: 0.3446 - learning_rate: 1.0000e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9287 - loss: 0.2980 — train_f1: 0.9660 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9284 - loss: 0.2986 - val_accuracy: 0.8850 - val_loss: 0.3470 - learning_rate: 1.0000e-04
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9203 - loss: 0.3243 — train_f1: 0.9660 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9201 - loss: 0.3243 - val_accuracy: 0.8850 - val_loss: 0.3428 - learning_rate: 1.0000e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9300 - loss: 0.3206 — train_f1: 0.9659 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9299 - loss: 0.3208 - val_accuracy: 0.8850 - val_loss: 0.3396 - learning_rate: 1.0000e-04
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9472 - loss: 0.2758 — train_f1: 0.9687 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 184ms/step - accuracy: 0.9472 - loss: 0.2759 - val_accuracy: 0.8850 - val_loss: 0.3427 - learning_rate: 1.0000e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9299 - loss: 0.3067
# Epoch 70: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#  — train_f1: 0.9699 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9300 - loss: 0.3065 - val_accuracy: 0.8850 - val_loss: 0.3395 - learning_rate: 1.0000e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9119 - loss: 0.3125 — train_f1: 0.9710 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 180ms/step - accuracy: 0.9125 - loss: 0.3118 - val_accuracy: 0.8900 - val_loss: 0.3357 - learning_rate: 5.0000e-05
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9342 - loss: 0.3019 — train_f1: 0.9722 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9337 - loss: 0.3024 - val_accuracy: 0.8900 - val_loss: 0.3335 - learning_rate: 5.0000e-05
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9251 - loss: 0.3117 — train_f1: 0.9723 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9252 - loss: 0.3113 - val_accuracy: 0.8900 - val_loss: 0.3326 - learning_rate: 5.0000e-05
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9340 - loss: 0.2766 — train_f1: 0.9736 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9337 - loss: 0.2770 - val_accuracy: 0.8850 - val_loss: 0.3317 - learning_rate: 5.0000e-05
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9205 - loss: 0.2891 — train_f1: 0.9724 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9207 - loss: 0.2889 - val_accuracy: 0.8850 - val_loss: 0.3317 - learning_rate: 5.0000e-05
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9198 - loss: 0.2986 — train_f1: 0.9761 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.9201 - loss: 0.2982 - val_accuracy: 0.8850 - val_loss: 0.3302 - learning_rate: 5.0000e-05
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9557 - loss: 0.2593 — train_f1: 0.9748 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9553 - loss: 0.2601 - val_accuracy: 0.8900 - val_loss: 0.3289 - learning_rate: 5.0000e-05
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9326 - loss: 0.2889 — train_f1: 0.9760 — val_f1: 0.8854
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9325 - loss: 0.2889 - val_accuracy: 0.8900 - val_loss: 0.3272 - learning_rate: 5.0000e-05
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9503 - loss: 0.2630 — train_f1: 0.9773 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.9503 - loss: 0.2630 - val_accuracy: 0.8900 - val_loss: 0.3274 - learning_rate: 5.0000e-05
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9359 - loss: 0.2635
# Epoch 80: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  — train_f1: 0.9761 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9359 - loss: 0.2635 - val_accuracy: 0.8850 - val_loss: 0.3281 - learning_rate: 5.0000e-05
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9325 - loss: 0.3115 — train_f1: 0.9749 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - accuracy: 0.9329 - loss: 0.3104 - val_accuracy: 0.8850 - val_loss: 0.3288 - learning_rate: 2.5000e-05
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9454 - loss: 0.2664
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  — train_f1: 0.9749 — val_f1: 0.8821
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.9454 - loss: 0.2667 - val_accuracy: 0.8850 - val_loss: 0.3293 - learning_rate: 2.5000e-05
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 78.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#               precision    recall  f1-score   support
#
#            0     0.8611    0.9300    0.8942       100
#            1     0.9239    0.8500    0.8854       100
#
#     accuracy                         0.8900       200
#    macro avg     0.8925    0.8900    0.8898       200
# weighted avg     0.8925    0.8900    0.8898       200

# %% [markdown]
# # BILSTM with Attention - 01

# %%
# ===== 0. Imports =====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import os, requests, zipfile

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, Input, Layer
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

# ===== 1. Download GloVe (100d) =====
glove_path = "glove.6B.100d.txt"
if not os.path.exists(glove_path):
    print("Downloading GloVe embeddings (~822MB zip)...")
    url = "http://nlp.stanford.edu/data/glove.6B.zip"
    r = requests.get(url, stream=True)
    with open("glove.6B.zip", "wb") as f:
        for chunk in r.iter_content(chunk_size=1024):
            if chunk:
                f.write(chunk)
    print("Extracting GloVe...")
    with zipfile.ZipFile("glove.6B.zip", "r") as zip_ref:
        zip_ref.extractall(".")
    print("GloVe ready!")

# ===== 2. Load Dataset =====
data = pd.read_csv("balanced_dataset.csv")  # must exist in Colab
labels = data['isBiased'].values.astype(int).reshape(-1,1)

# ===== 3. Preprocessing =====
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text

texts = [clean_text(t) for t in data['title'].astype(str)]

# ===== 4. Tokenization =====
max_words = 2000
max_len = 30
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

# ===== 5. Train/Validation Split =====
X_train, X_val, y_train, y_val = train_test_split(
    padded, labels, test_size=0.2, random_state=42, stratify=labels
)

# ===== 6. Load GloVe Embeddings =====
embedding_index = {}
with open(glove_path, encoding="utf8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = vector

embedding_dim = 100
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < max_words:
        vec = embedding_index.get(word)
        if vec is not None:
            embedding_matrix[i] = vec

# ===== 7. F1 Callback =====
class F1Metrics(Callback):
    def on_train_begin(self, logs=None):
        self.train_f1s = []
        self.val_f1s = []

    def on_epoch_end(self, epoch, logs=None):
        y_train_pred = (self.model.predict(X_train, verbose=0) > 0.5).astype(int)
        y_val_pred = (self.model.predict(X_val, verbose=0) > 0.5).astype(int)
        self.train_f1s.append(f1_score(y_train, y_train_pred))
        self.val_f1s.append(f1_score(y_val, y_val_pred))
        print(f" — train_f1: {self.train_f1s[-1]:.4f} — val_f1: {self.val_f1s[-1]:.4f}")

f1_callback = F1Metrics()

# ===== 8. Custom Attention Layer =====
class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(
            name="att_weight", shape=(input_shape[-1], 1),
            initializer="glorot_uniform", trainable=True
        )
        self.b = self.add_weight(
            name="att_bias", shape=(input_shape[1], 1),
            initializer="zeros", trainable=True
        )
        super(Attention, self).build(input_shape)

    def call(self, x):
        e = K.tanh(K.dot(x, self.W) + self.b)
        alpha = K.softmax(e, axis=1)
        context = x * alpha
        return K.sum(context, axis=1)

# ===== 9. Build BiLSTM + Attention Model =====
def build_bilstm_attention(max_words, embedding_dim, max_len, embedding_matrix):
    inputs = Input(shape=(max_len,))

    x = Embedding(input_dim=max_words,
                  output_dim=embedding_dim,
                  weights=[embedding_matrix],
                  input_length=max_len,
                  trainable=True)(inputs)

    x = Bidirectional(LSTM(24, return_sequences=True, dropout=0.5, recurrent_dropout=0.3))(x)  # neuron 32 -> 24 and dropout 0.4 -> 0.5

    x = Attention()(x)

    x = Dense(32, activation='relu', kernel_regularizer='l2')(x)
    x = Dropout(0.6)(x)                                                                       # dense dropout 0.5 -> 0.6

    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    optimizer = Adam(learning_rate=1e-4, clipnorm=1.0)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

model = build_bilstm_attention(max_words, embedding_dim, max_len, embedding_matrix)
model.summary()

# ===== 10. Callbacks =====
early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)

# ===== 11. Training =====
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr, f1_callback],
    verbose=1
)

# ===== 12. Plot Loss & F1 =====
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1,2,2)
plt.plot(f1_callback.train_f1s, label='train_f1')
plt.plot(f1_callback.val_f1s, label='val_f1')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Score Curve')
plt.legend()
plt.show()

# ===== 13. Evaluation =====
y_pred = (model.predict(X_val) > 0.5).astype(int)
print(classification_report(y_val, y_pred, digits=4))

cm = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Biased','Biased'],
            yticklabels=['Not Biased','Biased'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, 30, 100)        │       200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 30, 48)         │        24,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_1 (Attention)         │ (None, 48)             │            78 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,679 (881.56 KB)
#  Trainable params: 225,679 (881.56 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5062 - loss: 1.0783 — train_f1: 0.6478 — val_f1: 0.6639
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 318ms/step - accuracy: 0.5061 - loss: 1.0782 - val_accuracy: 0.6000 - val_loss: 1.0635 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5006 - loss: 1.0705 — train_f1: 0.6553 — val_f1: 0.6695
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.5009 - loss: 1.0703 - val_accuracy: 0.6100 - val_loss: 1.0535 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5760 - loss: 1.0527 — train_f1: 0.6360 — val_f1: 0.6727
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.5743 - loss: 1.0528 - val_accuracy: 0.6400 - val_loss: 1.0435 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5409 - loss: 1.0455 — train_f1: 0.6580 — val_f1: 0.6912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.5413 - loss: 1.0455 - val_accuracy: 0.6650 - val_loss: 1.0339 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5457 - loss: 1.0382 — train_f1: 0.6158 — val_f1: 0.6800
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.5468 - loss: 1.0379 - val_accuracy: 0.6800 - val_loss: 1.0238 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5380 - loss: 1.0303 — train_f1: 0.6443 — val_f1: 0.6897
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.5390 - loss: 1.0301 - val_accuracy: 0.6850 - val_loss: 1.0140 - learning_rate: 1.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5359 - loss: 1.0190 — train_f1: 0.6238 — val_f1: 0.6735
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.5360 - loss: 1.0189 - val_accuracy: 0.6800 - val_loss: 1.0040 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5699 - loss: 1.0048 — train_f1: 0.6356 — val_f1: 0.6872
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.5702 - loss: 1.0048 - val_accuracy: 0.6950 - val_loss: 0.9939 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5929 - loss: 1.0027 — train_f1: 0.6667 — val_f1: 0.7041
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.5923 - loss: 1.0026 - val_accuracy: 0.7100 - val_loss: 0.9843 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5842 - loss: 0.9947 — train_f1: 0.6811 — val_f1: 0.7077
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.5838 - loss: 0.9946 - val_accuracy: 0.7150 - val_loss: 0.9748 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5778 - loss: 0.9841 — train_f1: 0.6862 — val_f1: 0.7225
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - accuracy: 0.5784 - loss: 0.9839 - val_accuracy: 0.7350 - val_loss: 0.9652 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5672 - loss: 0.9741 — train_f1: 0.7070 — val_f1: 0.7551
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 218ms/step - accuracy: 0.5685 - loss: 0.9739 - val_accuracy: 0.7600 - val_loss: 0.9557 - learning_rate: 1.0000e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5863 - loss: 0.9641 — train_f1: 0.7214 — val_f1: 0.7614
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 212ms/step - accuracy: 0.5866 - loss: 0.9640 - val_accuracy: 0.7650 - val_loss: 0.9455 - learning_rate: 1.0000e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6048 - loss: 0.9498 — train_f1: 0.7610 — val_f1: 0.7614
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 179ms/step - accuracy: 0.6049 - loss: 0.9498 - val_accuracy: 0.7650 - val_loss: 0.9351 - learning_rate: 1.0000e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6173 - loss: 0.9411 — train_f1: 0.7578 — val_f1: 0.7629
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 203ms/step - accuracy: 0.6177 - loss: 0.9411 - val_accuracy: 0.7700 - val_loss: 0.9244 - learning_rate: 1.0000e-04
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.6153 - loss: 0.9406 — train_f1: 0.7636 — val_f1: 0.7629
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.6158 - loss: 0.9404 - val_accuracy: 0.7700 - val_loss: 0.9140 - learning_rate: 1.0000e-04
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6274 - loss: 0.9314 — train_f1: 0.7942 — val_f1: 0.7879
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.6276 - loss: 0.9314 - val_accuracy: 0.7900 - val_loss: 0.9032 - learning_rate: 1.0000e-04
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6194 - loss: 0.9186 — train_f1: 0.7963 — val_f1: 0.7959
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.6204 - loss: 0.9184 - val_accuracy: 0.8000 - val_loss: 0.8915 - learning_rate: 1.0000e-04
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6674 - loss: 0.9125 — train_f1: 0.8191 — val_f1: 0.8061
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.6666 - loss: 0.9124 - val_accuracy: 0.8100 - val_loss: 0.8794 - learning_rate: 1.0000e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7005 - loss: 0.8861 — train_f1: 0.8305 — val_f1: 0.8265
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.6996 - loss: 0.8862 - val_accuracy: 0.8300 - val_loss: 0.8661 - learning_rate: 1.0000e-04
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6891 - loss: 0.8891 — train_f1: 0.8414 — val_f1: 0.8325
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 261ms/step - accuracy: 0.6885 - loss: 0.8891 - val_accuracy: 0.8350 - val_loss: 0.8524 - learning_rate: 1.0000e-04
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6983 - loss: 0.8769 — train_f1: 0.8499 — val_f1: 0.8159
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.6972 - loss: 0.8769 - val_accuracy: 0.8150 - val_loss: 0.8381 - learning_rate: 1.0000e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6992 - loss: 0.8606 — train_f1: 0.8381 — val_f1: 0.8497
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7000 - loss: 0.8602 - val_accuracy: 0.8550 - val_loss: 0.8212 - learning_rate: 1.0000e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6970 - loss: 0.8598 — train_f1: 0.8475 — val_f1: 0.8438
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - accuracy: 0.6973 - loss: 0.8596 - val_accuracy: 0.8500 - val_loss: 0.8036 - learning_rate: 1.0000e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7336 - loss: 0.8333 — train_f1: 0.8542 — val_f1: 0.8410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 179ms/step - accuracy: 0.7338 - loss: 0.8331 - val_accuracy: 0.8450 - val_loss: 0.7839 - learning_rate: 1.0000e-04
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7244 - loss: 0.8238 — train_f1: 0.8614 — val_f1: 0.8293
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.7244 - loss: 0.8236 - val_accuracy: 0.8250 - val_loss: 0.7630 - learning_rate: 1.0000e-04
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7358 - loss: 0.8124 — train_f1: 0.8636 — val_f1: 0.8458
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.7361 - loss: 0.8122 - val_accuracy: 0.8450 - val_loss: 0.7415 - learning_rate: 1.0000e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7567 - loss: 0.7879 — train_f1: 0.8714 — val_f1: 0.8458
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.7573 - loss: 0.7874 - val_accuracy: 0.8450 - val_loss: 0.7162 - learning_rate: 1.0000e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7555 - loss: 0.7677 — train_f1: 0.8697 — val_f1: 0.8451
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 181ms/step - accuracy: 0.7553 - loss: 0.7676 - val_accuracy: 0.8350 - val_loss: 0.6902 - learning_rate: 1.0000e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7721 - loss: 0.7448 — train_f1: 0.8780 — val_f1: 0.8586
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.7720 - loss: 0.7448 - val_accuracy: 0.8650 - val_loss: 0.6613 - learning_rate: 1.0000e-04
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8158 - loss: 0.7207 — train_f1: 0.8813 — val_f1: 0.8485
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.8156 - loss: 0.7207 - val_accuracy: 0.8500 - val_loss: 0.6328 - learning_rate: 1.0000e-04
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.7974 - loss: 0.7074 — train_f1: 0.8858 — val_f1: 0.8513
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.7971 - loss: 0.7074 - val_accuracy: 0.8550 - val_loss: 0.6073 - learning_rate: 1.0000e-04
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8062 - loss: 0.6798 — train_f1: 0.8813 — val_f1: 0.8723
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 219ms/step - accuracy: 0.8061 - loss: 0.6796 - val_accuracy: 0.8800 - val_loss: 0.5860 - learning_rate: 1.0000e-04
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8268 - loss: 0.6536 — train_f1: 0.8917 — val_f1: 0.8788
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 179ms/step - accuracy: 0.8260 - loss: 0.6540 - val_accuracy: 0.8800 - val_loss: 0.5588 - learning_rate: 1.0000e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8184 - loss: 0.6259 — train_f1: 0.8943 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.8181 - loss: 0.6265 - val_accuracy: 0.8850 - val_loss: 0.5376 - learning_rate: 1.0000e-04
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7983 - loss: 0.6404 — train_f1: 0.8971 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.7986 - loss: 0.6403 - val_accuracy: 0.8850 - val_loss: 0.5229 - learning_rate: 1.0000e-04
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8434 - loss: 0.6002 — train_f1: 0.9023 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.8433 - loss: 0.6004 - val_accuracy: 0.8900 - val_loss: 0.5079 - learning_rate: 1.0000e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8575 - loss: 0.5704 — train_f1: 0.9063 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.8574 - loss: 0.5710 - val_accuracy: 0.8900 - val_loss: 0.4928 - learning_rate: 1.0000e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8347 - loss: 0.6037 — train_f1: 0.9027 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.8347 - loss: 0.6035 - val_accuracy: 0.8950 - val_loss: 0.4840 - learning_rate: 1.0000e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8374 - loss: 0.5840 — train_f1: 0.9046 — val_f1: 0.9053
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.8376 - loss: 0.5840 - val_accuracy: 0.9100 - val_loss: 0.4752 - learning_rate: 1.0000e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8210 - loss: 0.5697 — train_f1: 0.9086 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.8218 - loss: 0.5690 - val_accuracy: 0.8900 - val_loss: 0.4627 - learning_rate: 1.0000e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8336 - loss: 0.5734 — train_f1: 0.9100 — val_f1: 0.9016
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 260ms/step - accuracy: 0.8338 - loss: 0.5734 - val_accuracy: 0.9050 - val_loss: 0.4556 - learning_rate: 1.0000e-04
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8449 - loss: 0.5532 — train_f1: 0.9115 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 180ms/step - accuracy: 0.8453 - loss: 0.5529 - val_accuracy: 0.9000 - val_loss: 0.4462 - learning_rate: 1.0000e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8467 - loss: 0.5477 — train_f1: 0.9129 — val_f1: 0.9016
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.8468 - loss: 0.5478 - val_accuracy: 0.9050 - val_loss: 0.4376 - learning_rate: 1.0000e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8429 - loss: 0.5425 — train_f1: 0.9171 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 198ms/step - accuracy: 0.8434 - loss: 0.5419 - val_accuracy: 0.9000 - val_loss: 0.4319 - learning_rate: 1.0000e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8816 - loss: 0.4883 — train_f1: 0.9213 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8807 - loss: 0.4894 - val_accuracy: 0.9000 - val_loss: 0.4255 - learning_rate: 1.0000e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8840 - loss: 0.4900 — train_f1: 0.9213 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.8840 - loss: 0.4898 - val_accuracy: 0.8950 - val_loss: 0.4183 - learning_rate: 1.0000e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8687 - loss: 0.5117 — train_f1: 0.9241 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - accuracy: 0.8690 - loss: 0.5112 - val_accuracy: 0.8900 - val_loss: 0.4121 - learning_rate: 1.0000e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8591 - loss: 0.5132 — train_f1: 0.9241 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 181ms/step - accuracy: 0.8594 - loss: 0.5123 - val_accuracy: 0.8900 - val_loss: 0.4071 - learning_rate: 1.0000e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8775 - loss: 0.4857 — train_f1: 0.9272 — val_f1: 0.8788
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.8780 - loss: 0.4855 - val_accuracy: 0.8800 - val_loss: 0.4051 - learning_rate: 1.0000e-04
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8804 - loss: 0.4657 — train_f1: 0.9254 — val_f1: 0.9016
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 198ms/step - accuracy: 0.8804 - loss: 0.4663 - val_accuracy: 0.9050 - val_loss: 0.3966 - learning_rate: 1.0000e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8980 - loss: 0.4543 — train_f1: 0.9266 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.8974 - loss: 0.4552 - val_accuracy: 0.9100 - val_loss: 0.3908 - learning_rate: 1.0000e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8775 - loss: 0.4683 — train_f1: 0.9270 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.8781 - loss: 0.4676 - val_accuracy: 0.9000 - val_loss: 0.3872 - learning_rate: 1.0000e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8849 - loss: 0.4620 — train_f1: 0.9311 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.8851 - loss: 0.4617 - val_accuracy: 0.8850 - val_loss: 0.3855 - learning_rate: 1.0000e-04
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8778 - loss: 0.4526 — train_f1: 0.9321 — val_f1: 0.9016
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.8781 - loss: 0.4526 - val_accuracy: 0.9050 - val_loss: 0.3779 - learning_rate: 1.0000e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8714 - loss: 0.4677 — train_f1: 0.9321 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.8724 - loss: 0.4669 - val_accuracy: 0.9000 - val_loss: 0.3748 - learning_rate: 1.0000e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8869 - loss: 0.4478 — train_f1: 0.9345 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 186ms/step - accuracy: 0.8869 - loss: 0.4478 - val_accuracy: 0.9100 - val_loss: 0.3694 - learning_rate: 1.0000e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8834 - loss: 0.4259 — train_f1: 0.9316 — val_f1: 0.9110
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - accuracy: 0.8836 - loss: 0.4263 - val_accuracy: 0.9150 - val_loss: 0.3654 - learning_rate: 1.0000e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8836 - loss: 0.4322 — train_f1: 0.9335 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.8839 - loss: 0.4319 - val_accuracy: 0.9100 - val_loss: 0.3629 - learning_rate: 1.0000e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8775 - loss: 0.4567 — train_f1: 0.9345 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 181ms/step - accuracy: 0.8780 - loss: 0.4558 - val_accuracy: 0.9100 - val_loss: 0.3588 - learning_rate: 1.0000e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9036 - loss: 0.4079 — train_f1: 0.9374 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9034 - loss: 0.4080 - val_accuracy: 0.9100 - val_loss: 0.3564 - learning_rate: 1.0000e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8854 - loss: 0.4180 — train_f1: 0.9357 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 192ms/step - accuracy: 0.8856 - loss: 0.4180 - val_accuracy: 0.9100 - val_loss: 0.3521 - learning_rate: 1.0000e-04
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8867 - loss: 0.4171 — train_f1: 0.9407 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.8872 - loss: 0.4165 - val_accuracy: 0.9100 - val_loss: 0.3496 - learning_rate: 1.0000e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9098 - loss: 0.3768 — train_f1: 0.9421 — val_f1: 0.9062
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - accuracy: 0.9097 - loss: 0.3774 - val_accuracy: 0.9100 - val_loss: 0.3467 - learning_rate: 1.0000e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8973 - loss: 0.4087 — train_f1: 0.9430 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.8975 - loss: 0.4079 - val_accuracy: 0.9000 - val_loss: 0.3455 - learning_rate: 1.0000e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9142 - loss: 0.3785 — train_f1: 0.9454 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.9138 - loss: 0.3788 - val_accuracy: 0.9000 - val_loss: 0.3435 - learning_rate: 1.0000e-04
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9151 - loss: 0.3741  — train_f1: 0.9442 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9148 - loss: 0.3742 - val_accuracy: 0.8950 - val_loss: 0.3414 - learning_rate: 1.0000e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9042 - loss: 0.3838 — train_f1: 0.9454 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.9043 - loss: 0.3833 - val_accuracy: 0.8950 - val_loss: 0.3395 - learning_rate: 1.0000e-04
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8906 - loss: 0.4022 — train_f1: 0.9467 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 198ms/step - accuracy: 0.8908 - loss: 0.4020 - val_accuracy: 0.8950 - val_loss: 0.3380 - learning_rate: 1.0000e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9102 - loss: 0.3635 — train_f1: 0.9467 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.9102 - loss: 0.3638 - val_accuracy: 0.8950 - val_loss: 0.3362 - learning_rate: 1.0000e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9101 - loss: 0.3454 — train_f1: 0.9456 — val_f1: 0.8800
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.9104 - loss: 0.3450 - val_accuracy: 0.8800 - val_loss: 0.3381 - learning_rate: 1.0000e-04
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9005 - loss: 0.3702 — train_f1: 0.9491 — val_f1: 0.8889
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9008 - loss: 0.3700 - val_accuracy: 0.8900 - val_loss: 0.3331 - learning_rate: 1.0000e-04
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9165 - loss: 0.3358 — train_f1: 0.9468 — val_f1: 0.8889
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9169 - loss: 0.3358 - val_accuracy: 0.8900 - val_loss: 0.3333 - learning_rate: 1.0000e-04
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8843 - loss: 0.3713 — train_f1: 0.9491 — val_f1: 0.8889
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.8847 - loss: 0.3707 - val_accuracy: 0.8900 - val_loss: 0.3301 - learning_rate: 1.0000e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9074 - loss: 0.3430 — train_f1: 0.9504 — val_f1: 0.8945
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9078 - loss: 0.3429 - val_accuracy: 0.8950 - val_loss: 0.3279 - learning_rate: 1.0000e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9223 - loss: 0.3470 — train_f1: 0.9504 — val_f1: 0.8900
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9223 - loss: 0.3465 - val_accuracy: 0.8900 - val_loss: 0.3262 - learning_rate: 1.0000e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9218 - loss: 0.3263 — train_f1: 0.9552 — val_f1: 0.9016
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.9220 - loss: 0.3261 - val_accuracy: 0.9050 - val_loss: 0.3222 - learning_rate: 1.0000e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9219 - loss: 0.3503 — train_f1: 0.9531 — val_f1: 0.8889
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - accuracy: 0.9218 - loss: 0.3501 - val_accuracy: 0.8900 - val_loss: 0.3254 - learning_rate: 1.0000e-04
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9145 - loss: 0.3487
# Epoch 79: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#  — train_f1: 0.9531 — val_f1: 0.8900
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.9146 - loss: 0.3481 - val_accuracy: 0.8900 - val_loss: 0.3250 - learning_rate: 1.0000e-04
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9144 - loss: 0.3291 — train_f1: 0.9529 — val_f1: 0.9026
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.9145 - loss: 0.3290 - val_accuracy: 0.9050 - val_loss: 0.3213 - learning_rate: 5.0000e-05
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9042 - loss: 0.3360 — train_f1: 0.9555 — val_f1: 0.8934
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - accuracy: 0.9047 - loss: 0.3356 - val_accuracy: 0.8950 - val_loss: 0.3233 - learning_rate: 5.0000e-05
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9036 - loss: 0.3281
# Epoch 82: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  — train_f1: 0.9555 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 278ms/step - accuracy: 0.9040 - loss: 0.3279 - val_accuracy: 0.9000 - val_loss: 0.3224 - learning_rate: 5.0000e-05
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9252 - loss: 0.3315 — train_f1: 0.9555 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 183ms/step - accuracy: 0.9254 - loss: 0.3306 - val_accuracy: 0.9000 - val_loss: 0.3223 - learning_rate: 2.5000e-05
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9175 - loss: 0.3310
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  — train_f1: 0.9555 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 215ms/step - accuracy: 0.9174 - loss: 0.3312 - val_accuracy: 0.9000 - val_loss: 0.3220 - learning_rate: 2.5000e-05
# Epoch 84: early stopping
# Restoring model weights from the end of the best epoch: 80.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#               precision    recall  f1-score   support
#
#            0     0.8857    0.9300    0.9073       100
#            1     0.9263    0.8800    0.9026       100
#
#     accuracy                         0.9050       200
#    macro avg     0.9060    0.9050    0.9049       200
# weighted avg     0.9060    0.9050    0.9049       200

# %% [markdown]
# # BILSTM with Attention - 02

# %%
# ===== 0. Imports =====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import os, requests, zipfile

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, Input, Layer
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

# ===== 1. Download GloVe (100d) =====
glove_path = "glove.6B.100d.txt"
if not os.path.exists(glove_path):
    print("Downloading GloVe embeddings (~822MB zip)...")
    url = "http://nlp.stanford.edu/data/glove.6B.zip"
    r = requests.get(url, stream=True)
    with open("glove.6B.zip", "wb") as f:
        for chunk in r.iter_content(chunk_size=1024):
            if chunk:
                f.write(chunk)
    print("Extracting GloVe...")
    with zipfile.ZipFile("glove.6B.zip", "r") as zip_ref:
        zip_ref.extractall(".")
    print("GloVe ready!")

# ===== 2. Load Dataset =====
data = pd.read_csv("balanced_dataset.csv")  # must exist in Colab
labels = data['isBiased'].values.astype(int).reshape(-1,1)

# ===== 3. Preprocessing =====
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    return text

texts = [clean_text(t) for t in data['title'].astype(str)]

# ===== 4. Tokenization =====
max_words = 2000
max_len = 30
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

# ===== 5. Train/Validation Split =====
X_train, X_val, y_train, y_val = train_test_split(
    padded, labels, test_size=0.2, random_state=42, stratify=labels
)

# ===== 6. Load GloVe Embeddings =====
embedding_index = {}
with open(glove_path, encoding="utf8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = vector

embedding_dim = 100
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < max_words:
        vec = embedding_index.get(word)
        if vec is not None:
            embedding_matrix[i] = vec

# ===== 7. F1 Callback =====
class F1Metrics(Callback):
    def on_train_begin(self, logs=None):
        self.train_f1s = []
        self.val_f1s = []

    def on_epoch_end(self, epoch, logs=None):
        y_train_pred = (self.model.predict(X_train, verbose=0) > 0.5).astype(int)
        y_val_pred = (self.model.predict(X_val, verbose=0) > 0.5).astype(int)
        self.train_f1s.append(f1_score(y_train, y_train_pred))
        self.val_f1s.append(f1_score(y_val, y_val_pred))
        print(f" — train_f1: {self.train_f1s[-1]:.4f} — val_f1: {self.val_f1s[-1]:.4f}")

f1_callback = F1Metrics()

# ===== 8. Custom Attention Layer =====
class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(
            name="att_weight", shape=(input_shape[-1], 1),
            initializer="glorot_uniform", trainable=True
        )
        self.b = self.add_weight(
            name="att_bias", shape=(input_shape[1], 1),
            initializer="zeros", trainable=True
        )
        super(Attention, self).build(input_shape)

    def call(self, x):
        e = K.tanh(K.dot(x, self.W) + self.b)
        alpha = K.softmax(e, axis=1)
        context = x * alpha
        return K.sum(context, axis=1)

# ===== 9. Build BiLSTM + Attention Model =====
def build_bilstm_attention(max_words, embedding_dim, max_len, embedding_matrix):
    inputs = Input(shape=(max_len,))

    x = Embedding(input_dim=max_words,
                  output_dim=embedding_dim,
                  weights=[embedding_matrix],
                  input_length=max_len,
                  trainable=True)(inputs)

    x = Bidirectional(LSTM(24, return_sequences=True, dropout=0.5, recurrent_dropout=0.3))(x)  # neuron 32 -> 24 and dropout 0.4 -> 0.5

    x = Attention()(x)

    x = Dense(32, activation='relu', kernel_regularizer='l2')(x)
    x = Dropout(0.6)(x)                                                                       # dense dropout 0.5 -> 0.6

    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    optimizer = Adam(learning_rate=1e-4, clipnorm=1.0)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

model = build_bilstm_attention(max_words, embedding_dim, max_len, embedding_matrix)
model.summary()

# ===== 10. Callbacks =====
early_stop = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True, verbose=1)            # increased patience 4 -> 6
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)                        # increased patience 2 -> 3

# ===== 11. Training =====
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr, f1_callback],
    verbose=1
)

# ===== 12. Plot Loss & F1 =====
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1,2,2)
plt.plot(f1_callback.train_f1s, label='train_f1')
plt.plot(f1_callback.val_f1s, label='val_f1')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Score Curve')
plt.legend()
plt.show()

# ===== 13. Evaluation =====
y_pred = (model.predict(X_val) > 0.5).astype(int)
print(classification_report(y_val, y_pred, digits=4))

cm = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Biased','Biased'],
            yticklabels=['Not Biased','Biased'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_3 (Embedding)         │ (None, 30, 100)        │       200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 30, 48)         │        24,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_3 (Attention)         │ (None, 48)             │            78 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,679 (881.56 KB)
#  Trainable params: 225,679 (881.56 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5549 - loss: 1.0716 — train_f1: 0.3196 — val_f1: 0.3733
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 0.5539 - loss: 1.0716 - val_accuracy: 0.5300 - val_loss: 1.0658 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5210 - loss: 1.0650 — train_f1: 0.4196 — val_f1: 0.4512
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.5201 - loss: 1.0650 - val_accuracy: 0.5500 - val_loss: 1.0557 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.4862 - loss: 1.0564 — train_f1: 0.4796 — val_f1: 0.5202
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.4862 - loss: 1.0564 - val_accuracy: 0.5850 - val_loss: 1.0460 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4926 - loss: 1.0478 — train_f1: 0.5749 — val_f1: 0.6429
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - accuracy: 0.4926 - loss: 1.0478 - val_accuracy: 0.6500 - val_loss: 1.0365 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5393 - loss: 1.0378 — train_f1: 0.6179 — val_f1: 0.6731
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 234ms/step - accuracy: 0.5385 - loss: 1.0378 - val_accuracy: 0.6600 - val_loss: 1.0277 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5192 - loss: 1.0287 — train_f1: 0.6502 — val_f1: 0.6919
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - accuracy: 0.5195 - loss: 1.0286 - val_accuracy: 0.6750 - val_loss: 1.0187 - learning_rate: 1.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.4952 - loss: 1.0233 — train_f1: 0.6891 — val_f1: 0.7175
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.4959 - loss: 1.0231 - val_accuracy: 0.6850 - val_loss: 1.0096 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5400 - loss: 1.0072 — train_f1: 0.7028 — val_f1: 0.7342
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 249ms/step - accuracy: 0.5402 - loss: 1.0072 - val_accuracy: 0.6850 - val_loss: 1.0007 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5343 - loss: 1.0034 — train_f1: 0.7041 — val_f1: 0.7424
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 201ms/step - accuracy: 0.5338 - loss: 1.0034 - val_accuracy: 0.7050 - val_loss: 0.9921 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5391 - loss: 1.0006 — train_f1: 0.7107 — val_f1: 0.7349
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.5391 - loss: 1.0004 - val_accuracy: 0.7150 - val_loss: 0.9837 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5172 - loss: 0.9903 — train_f1: 0.7179 — val_f1: 0.7404
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.5176 - loss: 0.9903 - val_accuracy: 0.7300 - val_loss: 0.9755 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6038 - loss: 0.9770 — train_f1: 0.7292 — val_f1: 0.7442
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.6034 - loss: 0.9769 - val_accuracy: 0.7250 - val_loss: 0.9674 - learning_rate: 1.0000e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5228 - loss: 0.9748 — train_f1: 0.7232 — val_f1: 0.7560
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.5241 - loss: 0.9746 - val_accuracy: 0.7450 - val_loss: 0.9592 - learning_rate: 1.0000e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5678 - loss: 0.9594 — train_f1: 0.7251 — val_f1: 0.7576
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.5675 - loss: 0.9594 - val_accuracy: 0.7600 - val_loss: 0.9509 - learning_rate: 1.0000e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5648 - loss: 0.9575 — train_f1: 0.7243 — val_f1: 0.7551
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 202ms/step - accuracy: 0.5650 - loss: 0.9574 - val_accuracy: 0.7600 - val_loss: 0.9428 - learning_rate: 1.0000e-04
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5645 - loss: 0.9483 — train_f1: 0.7307 — val_f1: 0.7629
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.5648 - loss: 0.9483 - val_accuracy: 0.7700 - val_loss: 0.9347 - learning_rate: 1.0000e-04
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5663 - loss: 0.9415 — train_f1: 0.7526 — val_f1: 0.7778
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 225ms/step - accuracy: 0.5662 - loss: 0.9414 - val_accuracy: 0.7800 - val_loss: 0.9266 - learning_rate: 1.0000e-04
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5954 - loss: 0.9351 — train_f1: 0.7567 — val_f1: 0.7795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.5957 - loss: 0.9350 - val_accuracy: 0.7850 - val_loss: 0.9180 - learning_rate: 1.0000e-04
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5913 - loss: 0.9229 — train_f1: 0.7486 — val_f1: 0.7812
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.5915 - loss: 0.9230 - val_accuracy: 0.7900 - val_loss: 0.9093 - learning_rate: 1.0000e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6080 - loss: 0.9184 — train_f1: 0.7571 — val_f1: 0.7772
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.6077 - loss: 0.9183 - val_accuracy: 0.7850 - val_loss: 0.9011 - learning_rate: 1.0000e-04
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5902 - loss: 0.9153 — train_f1: 0.7768 — val_f1: 0.7857
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.5910 - loss: 0.9151 - val_accuracy: 0.7900 - val_loss: 0.8924 - learning_rate: 1.0000e-04
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6242 - loss: 0.8994 — train_f1: 0.7820 — val_f1: 0.8020
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 180ms/step - accuracy: 0.6235 - loss: 0.8994 - val_accuracy: 0.8050 - val_loss: 0.8830 - learning_rate: 1.0000e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6359 - loss: 0.8934 — train_f1: 0.7868 — val_f1: 0.8061
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.6353 - loss: 0.8934 - val_accuracy: 0.8100 - val_loss: 0.8734 - learning_rate: 1.0000e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6633 - loss: 0.8811 — train_f1: 0.7903 — val_f1: 0.8041
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.6626 - loss: 0.8812 - val_accuracy: 0.8100 - val_loss: 0.8626 - learning_rate: 1.0000e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6469 - loss: 0.8771 — train_f1: 0.8000 — val_f1: 0.8144
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.6473 - loss: 0.8770 - val_accuracy: 0.8200 - val_loss: 0.8517 - learning_rate: 1.0000e-04
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6047 - loss: 0.8744 — train_f1: 0.7895 — val_f1: 0.8316
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.6056 - loss: 0.8743 - val_accuracy: 0.8400 - val_loss: 0.8405 - learning_rate: 1.0000e-04
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6841 - loss: 0.8587 — train_f1: 0.8342 — val_f1: 0.8400
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.6843 - loss: 0.8586 - val_accuracy: 0.8400 - val_loss: 0.8269 - learning_rate: 1.0000e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6820 - loss: 0.8508 — train_f1: 0.8279 — val_f1: 0.8265
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 181ms/step - accuracy: 0.6820 - loss: 0.8507 - val_accuracy: 0.8300 - val_loss: 0.8126 - learning_rate: 1.0000e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7247 - loss: 0.8297 — train_f1: 0.8359 — val_f1: 0.8325
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 216ms/step - accuracy: 0.7243 - loss: 0.8296 - val_accuracy: 0.8350 - val_loss: 0.7955 - learning_rate: 1.0000e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7512 - loss: 0.8222 — train_f1: 0.8564 — val_f1: 0.8458
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7502 - loss: 0.8221 - val_accuracy: 0.8450 - val_loss: 0.7770 - learning_rate: 1.0000e-04
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6968 - loss: 0.8179 — train_f1: 0.8659 — val_f1: 0.8529
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.6970 - loss: 0.8177 - val_accuracy: 0.8500 - val_loss: 0.7572 - learning_rate: 1.0000e-04
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6798 - loss: 0.8050 — train_f1: 0.8615 — val_f1: 0.8513
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.6815 - loss: 0.8046 - val_accuracy: 0.8550 - val_loss: 0.7345 - learning_rate: 1.0000e-04
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7551 - loss: 0.7813 — train_f1: 0.8676 — val_f1: 0.8641
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7558 - loss: 0.7808 - val_accuracy: 0.8600 - val_loss: 0.7083 - learning_rate: 1.0000e-04
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7669 - loss: 0.7651 — train_f1: 0.8702 — val_f1: 0.8670
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 223ms/step - accuracy: 0.7666 - loss: 0.7649 - val_accuracy: 0.8650 - val_loss: 0.6813 - learning_rate: 1.0000e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8057 - loss: 0.7249 — train_f1: 0.8722 — val_f1: 0.8713
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 186ms/step - accuracy: 0.8057 - loss: 0.7244 - val_accuracy: 0.8700 - val_loss: 0.6504 - learning_rate: 1.0000e-04
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7754 - loss: 0.7158 — train_f1: 0.8798 — val_f1: 0.8788
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.7755 - loss: 0.7156 - val_accuracy: 0.8800 - val_loss: 0.6190 - learning_rate: 1.0000e-04
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8201 - loss: 0.6765 — train_f1: 0.8881 — val_f1: 0.8731
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 209ms/step - accuracy: 0.8200 - loss: 0.6764 - val_accuracy: 0.8750 - val_loss: 0.5862 - learning_rate: 1.0000e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8164 - loss: 0.6536 — train_f1: 0.8956 — val_f1: 0.8731
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - accuracy: 0.8166 - loss: 0.6533 - val_accuracy: 0.8750 - val_loss: 0.5577 - learning_rate: 1.0000e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7994 - loss: 0.6479 — train_f1: 0.9001 — val_f1: 0.8731
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.7991 - loss: 0.6476 - val_accuracy: 0.8750 - val_loss: 0.5339 - learning_rate: 1.0000e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8240 - loss: 0.6071 — train_f1: 0.8988 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.8242 - loss: 0.6070 - val_accuracy: 0.8850 - val_loss: 0.5122 - learning_rate: 1.0000e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8168 - loss: 0.6031 — train_f1: 0.9023 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.8172 - loss: 0.6034 - val_accuracy: 0.8850 - val_loss: 0.4939 - learning_rate: 1.0000e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8485 - loss: 0.5558 — train_f1: 0.9072 — val_f1: 0.8832
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 197ms/step - accuracy: 0.8481 - loss: 0.5562 - val_accuracy: 0.8850 - val_loss: 0.4794 - learning_rate: 1.0000e-04
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8519 - loss: 0.5476 — train_f1: 0.9079 — val_f1: 0.8945
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.8516 - loss: 0.5476 - val_accuracy: 0.8950 - val_loss: 0.4666 - learning_rate: 1.0000e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8621 - loss: 0.5255 — train_f1: 0.9107 — val_f1: 0.8945
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.8620 - loss: 0.5261 - val_accuracy: 0.8950 - val_loss: 0.4563 - learning_rate: 1.0000e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8248 - loss: 0.5614 — train_f1: 0.9105 — val_f1: 0.8945
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - accuracy: 0.8259 - loss: 0.5608 - val_accuracy: 0.8950 - val_loss: 0.4489 - learning_rate: 1.0000e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8543 - loss: 0.5347 — train_f1: 0.9128 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.8544 - loss: 0.5341 - val_accuracy: 0.8950 - val_loss: 0.4406 - learning_rate: 1.0000e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8665 - loss: 0.5077 — train_f1: 0.9074 — val_f1: 0.8808
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - accuracy: 0.8666 - loss: 0.5079 - val_accuracy: 0.8850 - val_loss: 0.4335 - learning_rate: 1.0000e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8633 - loss: 0.5146 — train_f1: 0.9195 — val_f1: 0.8934
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.8630 - loss: 0.5149 - val_accuracy: 0.8950 - val_loss: 0.4280 - learning_rate: 1.0000e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8668 - loss: 0.5115 — train_f1: 0.9124 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 228ms/step - accuracy: 0.8668 - loss: 0.5115 - val_accuracy: 0.8950 - val_loss: 0.4219 - learning_rate: 1.0000e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8764 - loss: 0.4946 — train_f1: 0.9166 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.8760 - loss: 0.4950 - val_accuracy: 0.8950 - val_loss: 0.4173 - learning_rate: 1.0000e-04
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8926 - loss: 0.4492 — train_f1: 0.9164 — val_f1: 0.8866
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.8921 - loss: 0.4496 - val_accuracy: 0.8900 - val_loss: 0.4112 - learning_rate: 1.0000e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8725 - loss: 0.4768 — train_f1: 0.9262 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - accuracy: 0.8727 - loss: 0.4768 - val_accuracy: 0.9000 - val_loss: 0.4080 - learning_rate: 1.0000e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9069 - loss: 0.4546 — train_f1: 0.9288 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.9064 - loss: 0.4546 - val_accuracy: 0.8950 - val_loss: 0.4031 - learning_rate: 1.0000e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8791 - loss: 0.4495 — train_f1: 0.9274 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.8788 - loss: 0.4498 - val_accuracy: 0.8900 - val_loss: 0.3996 - learning_rate: 1.0000e-04
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8902 - loss: 0.4349 — train_f1: 0.9298 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.8897 - loss: 0.4360 - val_accuracy: 0.8950 - val_loss: 0.3951 - learning_rate: 1.0000e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8753 - loss: 0.4750 — train_f1: 0.9313 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - accuracy: 0.8759 - loss: 0.4746 - val_accuracy: 0.8950 - val_loss: 0.3913 - learning_rate: 1.0000e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8769 - loss: 0.4640 — train_f1: 0.9308 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.8770 - loss: 0.4635 - val_accuracy: 0.9000 - val_loss: 0.3860 - learning_rate: 1.0000e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8942 - loss: 0.4081 — train_f1: 0.9313 — val_f1: 0.8878
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 220ms/step - accuracy: 0.8938 - loss: 0.4090 - val_accuracy: 0.8900 - val_loss: 0.3835 - learning_rate: 1.0000e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8746 - loss: 0.4293 — train_f1: 0.9323 — val_f1: 0.8969
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 186ms/step - accuracy: 0.8750 - loss: 0.4288 - val_accuracy: 0.9000 - val_loss: 0.3794 - learning_rate: 1.0000e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8632 - loss: 0.4383 — train_f1: 0.9352 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.8640 - loss: 0.4378 - val_accuracy: 0.8950 - val_loss: 0.3770 - learning_rate: 1.0000e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9029 - loss: 0.4322 — train_f1: 0.9395 — val_f1: 0.8990
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.9030 - loss: 0.4317 - val_accuracy: 0.9000 - val_loss: 0.3755 - learning_rate: 1.0000e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8971 - loss: 0.4338 — train_f1: 0.9419 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 212ms/step - accuracy: 0.8970 - loss: 0.4336 - val_accuracy: 0.8950 - val_loss: 0.3723 - learning_rate: 1.0000e-04
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8935 - loss: 0.4101 — train_f1: 0.9373 — val_f1: 0.8912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.8932 - loss: 0.4106 - val_accuracy: 0.8950 - val_loss: 0.3685 - learning_rate: 1.0000e-04
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9232 - loss: 0.3875 — train_f1: 0.9354 — val_f1: 0.8912
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.9227 - loss: 0.3879 - val_accuracy: 0.8950 - val_loss: 0.3665 - learning_rate: 1.0000e-04
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8943 - loss: 0.4270 — train_f1: 0.9400 — val_f1: 0.8923
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.8945 - loss: 0.4262 - val_accuracy: 0.8950 - val_loss: 0.3639 - learning_rate: 1.0000e-04
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8874 - loss: 0.4112 — train_f1: 0.9444 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.8875 - loss: 0.4109 - val_accuracy: 0.9000 - val_loss: 0.3644 - learning_rate: 1.0000e-04
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8977 - loss: 0.3909 — train_f1: 0.9446 — val_f1: 0.9045
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.8977 - loss: 0.3907 - val_accuracy: 0.9050 - val_loss: 0.3636 - learning_rate: 1.0000e-04
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8990 - loss: 0.3881 — train_f1: 0.9444 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.8989 - loss: 0.3883 - val_accuracy: 0.9000 - val_loss: 0.3614 - learning_rate: 1.0000e-04
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9144 - loss: 0.3681 — train_f1: 0.9455 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.9139 - loss: 0.3686 - val_accuracy: 0.9000 - val_loss: 0.3570 - learning_rate: 1.0000e-04
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9285 - loss: 0.3377 — train_f1: 0.9467 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9280 - loss: 0.3386 - val_accuracy: 0.9000 - val_loss: 0.3556 - learning_rate: 1.0000e-04
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8950 - loss: 0.3805 — train_f1: 0.9468 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 201ms/step - accuracy: 0.8953 - loss: 0.3804 - val_accuracy: 0.9000 - val_loss: 0.3534 - learning_rate: 1.0000e-04
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9008 - loss: 0.3965 — train_f1: 0.9476 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.9011 - loss: 0.3951 - val_accuracy: 0.9000 - val_loss: 0.3490 - learning_rate: 1.0000e-04
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9102 - loss: 0.3581 — train_f1: 0.9517 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 235ms/step - accuracy: 0.9101 - loss: 0.3582 - val_accuracy: 0.9000 - val_loss: 0.3477 - learning_rate: 1.0000e-04
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9138 - loss: 0.3412 — train_f1: 0.9492 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.9133 - loss: 0.3420 - val_accuracy: 0.9000 - val_loss: 0.3461 - learning_rate: 1.0000e-04
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9074 - loss: 0.3525 — train_f1: 0.9517 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - accuracy: 0.9077 - loss: 0.3520 - val_accuracy: 0.9000 - val_loss: 0.3434 - learning_rate: 1.0000e-04
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9212 - loss: 0.3265 — train_f1: 0.9494 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 202ms/step - accuracy: 0.9203 - loss: 0.3279 - val_accuracy: 0.9000 - val_loss: 0.3442 - learning_rate: 1.0000e-04
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9274 - loss: 0.3224 — train_f1: 0.9518 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.9272 - loss: 0.3229 - val_accuracy: 0.9000 - val_loss: 0.3433 - learning_rate: 1.0000e-04
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9103 - loss: 0.3413
# Epoch 78: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#  — train_f1: 0.9519 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9104 - loss: 0.3410 - val_accuracy: 0.9000 - val_loss: 0.3443 - learning_rate: 1.0000e-04
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9311 - loss: 0.3226 — train_f1: 0.9531 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9307 - loss: 0.3229 - val_accuracy: 0.9000 - val_loss: 0.3438 - learning_rate: 5.0000e-05
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9016 - loss: 0.3623 — train_f1: 0.9543 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9020 - loss: 0.3615 - val_accuracy: 0.9000 - val_loss: 0.3425 - learning_rate: 5.0000e-05
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8988 - loss: 0.3657 — train_f1: 0.9531 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.8988 - loss: 0.3653 - val_accuracy: 0.9000 - val_loss: 0.3420 - learning_rate: 5.0000e-05
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9098 - loss: 0.3283 — train_f1: 0.9531 — val_f1: 0.9036
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - accuracy: 0.9097 - loss: 0.3285 - val_accuracy: 0.9050 - val_loss: 0.3420 - learning_rate: 5.0000e-05
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9229 - loss: 0.3305 — train_f1: 0.9531 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.9227 - loss: 0.3309 - val_accuracy: 0.9000 - val_loss: 0.3411 - learning_rate: 5.0000e-05
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9080 - loss: 0.3324 — train_f1: 0.9543 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9083 - loss: 0.3320 - val_accuracy: 0.9000 - val_loss: 0.3399 - learning_rate: 5.0000e-05
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9314 - loss: 0.3137 — train_f1: 0.9542 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - accuracy: 0.9310 - loss: 0.3143 - val_accuracy: 0.9000 - val_loss: 0.3379 - learning_rate: 5.0000e-05
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9033 - loss: 0.3647 — train_f1: 0.9529 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 187ms/step - accuracy: 0.9033 - loss: 0.3642 - val_accuracy: 0.9000 - val_loss: 0.3367 - learning_rate: 5.0000e-05
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9115 - loss: 0.3252 — train_f1: 0.9543 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.9116 - loss: 0.3249 - val_accuracy: 0.9000 - val_loss: 0.3367 - learning_rate: 5.0000e-05
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9336 - loss: 0.3049 — train_f1: 0.9542 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.9333 - loss: 0.3055 - val_accuracy: 0.9000 - val_loss: 0.3354 - learning_rate: 5.0000e-05
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9210 - loss: 0.3237 — train_f1: 0.9543 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.9208 - loss: 0.3239 - val_accuracy: 0.9000 - val_loss: 0.3360 - learning_rate: 5.0000e-05
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8978 - loss: 0.3525 — train_f1: 0.9555 — val_f1: 0.8980
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.8985 - loss: 0.3512 - val_accuracy: 0.9000 - val_loss: 0.3350 - learning_rate: 5.0000e-05
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9132 - loss: 0.3339 — train_f1: 0.9555 — val_f1: 0.9036
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.9134 - loss: 0.3333 - val_accuracy: 0.9050 - val_loss: 0.3352 - learning_rate: 5.0000e-05
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9352 - loss: 0.3018 — train_f1: 0.9544 — val_f1: 0.9045
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.9353 - loss: 0.3013 - val_accuracy: 0.9050 - val_loss: 0.3370 - learning_rate: 5.0000e-05
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9454 - loss: 0.2855
# Epoch 93: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  — train_f1: 0.9544 — val_f1: 0.9045
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.9451 - loss: 0.2858 - val_accuracy: 0.9050 - val_loss: 0.3377 - learning_rate: 5.0000e-05
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9324 - loss: 0.3087 — train_f1: 0.9544 — val_f1: 0.9045
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - accuracy: 0.9317 - loss: 0.3094 - val_accuracy: 0.9050 - val_loss: 0.3373 - learning_rate: 2.5000e-05
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8907 - loss: 0.3665 — train_f1: 0.9569 — val_f1: 0.9045
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - accuracy: 0.8914 - loss: 0.3651 - val_accuracy: 0.9050 - val_loss: 0.3359 - learning_rate: 2.5000e-05
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9325 - loss: 0.3015
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  — train_f1: 0.9569 — val_f1: 0.9045
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.9320 - loss: 0.3021 - val_accuracy: 0.9050 - val_loss: 0.3355 - learning_rate: 2.5000e-05
# Epoch 96: early stopping
# Restoring model weights from the end of the best epoch: 90.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#               precision    recall  f1-score   support
#
#            0     0.8846    0.9200    0.9020       100
#            1     0.9167    0.8800    0.8980       100
#
#     accuracy                         0.9000       200
#    macro avg     0.9006    0.9000    0.9000       200
# weighted avg     0.9006    0.9000    0.9000       200
